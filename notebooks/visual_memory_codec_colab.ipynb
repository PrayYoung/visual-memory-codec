# %% [markdown]
# # Visual Memory Codec
#
# Efficient persistent representations for machine visual memory.
#
# This notebook is the GPU execution path for the natural-image benchmark.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
REPO_URL = 'https://github.com/YOUR_USERNAME/visual-memory-codec.git'
WORKDIR = '/content/visual-memory-codec'
OUTPUT_COPY_DIR = '/content/drive/MyDrive/visual-memory-codec-outputs'

# !rm -rf $WORKDIR
# !git clone $REPO_URL $WORKDIR
# %cd $WORKDIR

# %%
# !python3 -m pip install -q --upgrade pip
# !python3 -m pip install -q -r requirements-colab.txt

# %%
import torch
print('torch', torch.__version__)
print('cuda_available', torch.cuda.is_available())
if torch.cuda.is_available():
    print('gpu', torch.cuda.get_device_name(0))
else:
    raise RuntimeError('CUDA is not available. Switch Colab runtime to GPU.')

# %%
# !python3 scripts/prepare_coco_subset.py --output-dir data/coco --num-samples 64 --min-annotations 3 --min-categories 2

# %%
# !PYTHONPATH=src python3 -m visual_memory_benchmark.run --config configs/natural_coco_mvp.json

# %%
# !mkdir -p $OUTPUT_COPY_DIR
# !cp -R outputs/natural_coco_mvp $OUTPUT_COPY_DIR/
# !ls -lah outputs/natural_coco_mvp
